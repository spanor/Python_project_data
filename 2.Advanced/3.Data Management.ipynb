# %%
import pandas as pd 
from datasets import load_dataset
import matplotlib.pyplot as plt 

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df.sample(3 , random_state = 43)
# Out:
#           job_title_short                 job_title       job_location  \
# 50399      Data Scientist  Director of Data Science  San Francisco, CA
# 291453       Data Analyst              Data Analyst  Moncks Corner, SC
# 221974  Software Engineer   Senior Backend Engineer      Paris, France
#
#                         job_via job_schedule_type  job_work_from_home  \
# 50399               via Ladders         Full-time               False
# 291453                via Nexxt         Full-time               False
# 221974  via Emplois Trabajo.org         Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 50399   California, United States 2023-04-22 06:02:30                  False
# 291453                    Georgia 2023-10-20 17:48:29                  False
# 221974                     France 2023-03-17 22:37:57                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# ...

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original
df_altered.iloc[:4, 11:14]
print(df_altered)
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
median_salary_avg = df_altered['salary_year_avg'].median()
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary_avg)
print(df_altered['salary_year_avg'])
# Out:
# 0         115000.0
# 1         115000.0
# 2         115000.0
# 3         115000.0
# 4         115000.0
#             ...
# 785736    115000.0
# 785737    115000.0
# 785738    115000.0
# 785739    115000.0
# 785740    115000.0
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
id(df_altered)==id(df_original)
# Out:
# True

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original.copy()

# %%
id('df_altered')==id(df_original)
# Out:
# False

# %%
df_original.sample(n=5)
# Out:
#           job_title_short                               job_title  \
# 155691      Data Engineer                           Data Engineer
# 60806      Data Scientist                          Data Scientist
# 515265  Software Engineer             Application Support Analyst
# 487410      Data Engineer           Data Engineer - Observability
# 446949     Data Scientist  Senior Machine Learning Data Scientist
#
#                              job_location              job_via  \
# 155691                           Anywhere         via LinkedIn
# 60806                           Singapore  via BeBee Singapore
# 515265  Taguig, Metro Manila, Philippines      via Trabajo.org
# 487410                         New Jersey           via Adzuna
# 446949                      United States      via Trabajo.org
#
#        job_schedule_type  job_work_from_home search_location  \
# 155691         Full-time                True         Romania
# 60806          Full-time               False       Singapore
# ...

# %%
df_original.sample(frac=0.00001, replace = False)
# Out:
#                   job_title_short  \
# 459718           Business Analyst
# 16534               Data Engineer
# 758353               Data Analyst
# 58188           Software Engineer
# 147992             Data Scientist
# 300213           Business Analyst
# 746920  Machine Learning Engineer
# 428532               Data Analyst
#
#                                                 job_title  \
# 459718                                         BI Analyst
# 16534                                       Data Engineer
# 758353                                       Data Analyst
# 58188   Senior Backend Engineer (Golang) - Studio Expl...
# 147992                                   Campaign Analyst
# 300213                   Business Intelligence Analyst II
# 746920    Principal Scientist in Machine Learning (m/f/d)
# 428532                      Reporting & Analytics Manager
#
#                                              job_location  \
# 459718                                     Warsaw, Poland
# ...

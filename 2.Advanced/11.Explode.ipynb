# %%
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
data = {
    'job_title_short': ['Data Analyst', 'Data Scientist', 'Data Engineer'],
    'job_skills': [['excel', 'sql', 'python'], ['python', 'r'], ['aws', 'python', 'airflow']]
}

df_skills = pd.DataFrame(data)
df_skills
# Out:
#   job_title_short              job_skills
# 0    Data Analyst    [excel, sql, python]
# 1  Data Scientist             [python, r]
# 2   Data Engineer  [aws, python, airflow]

# %%
df_exploded = df_skills.explode('job_skills')
df_exploded
# Out:
#   job_title_short job_skills
# 0    Data Analyst      excel
# 0    Data Analyst        sql
# 0    Data Analyst     python
# 1  Data Scientist     python
# 1  Data Scientist          r
# 2   Data Engineer        aws
# 2   Data Engineer     python
# 2   Data Engineer    airflow

# %%
df_count = df_exploded.value_counts('job_skills')
df_count
# Out:
# job_skills
# python     3
# airflow    1
# aws        1
# excel      1
# r          1
# sql        1
# Name: count, dtype: int64

# %%
df_count.plot(kind = 'bar')
# Out:
# <Axes: xlabel='job_skills'>

# %%
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df[['job_title_short','job_skills']].head(5)
# Out:
#         job_title_short                                         job_skills
# 0  Senior Data Engineer                                               None
# 1          Data Analyst         [r, python, sql, nosql, power bi, tableau]
# 2         Data Engineer  [python, sql, c#, azure, airflow, dax, docker,...
# 3         Data Engineer  [python, c++, java, matlab, aws, tensorflow, k...
# 4         Data Engineer  [bash, python, oracle, aws, ansible, puppet, j...

# %%
df_exploded = df.explode('job_skills')
df_exploded
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
df_exploded['job_skills'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='job_skills'>

# %%
##Calculate Skill Count. T
# Then clean up the skills.
# Now we'll calculate the skill count for each data job.
# We'll reset_index to transform skills_count from a Series to a DataFrame.
# We'll prep for plotting by the data getting in descending order.
# Finally, we'll graph the top 10 skills using a bar chart.

import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_skills = df.copy()

# %%
df_skills = df_skills.explode('job_skills')
df_skills
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
skills_counts = pd.pivot_table(df_skills, columns = ['job_skills','job_title_short'], aggfunc = 'count')
skills_counts
# Out:
# job_skills                     airflow                              \
# job_title_short       Business Analyst Cloud Engineer Data Analyst
# company_name                       318            260         2002
# job_country                        318            260         2002
# job_health_insurance               318            260         2002
# job_location                       318            260         1997
# job_no_degree_mention              318            260         2002
# job_posted_date                    318            260         2002
# job_schedule_type                  308            258         1981
# job_title                          318            260         2002
# job_type_skills                    318            260         2002
# job_via                            318            260         2002
# job_work_from_home                 318            260         2002
# salary_hour_avg                      1              5           19
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_exploded = df.explode('job_skills')

# %%
skills_count = df_exploded.groupby(['job_title_short','job_skills']).size()
type(skills_count)
# Out:
# pandas.core.series.Series

# %%
df_skills_count = skills_count.reset_index(name = 'skill_count')
df_skills_count
df_skills_count = df_skills_count.sort_values(by = 'skill_count', ascending = False)
df_skills_count
# Out:
#        job_title_short  job_skills  skill_count
# 1066    Data Scientist      python       113711
# 865      Data Engineer         sql       113130
# 830      Data Engineer      python       108022
# 625       Data Analyst         sql        92428
# 1101    Data Scientist         sql        78982
# ...                ...         ...          ...
# 462       Data Analyst     chainer            1
# 432     Cloud Engineer       wrike            1
# 410     Cloud Engineer      theano            1
# 24    Business Analyst     chainer            1
# 29    Business Analyst  codecommit            1
#
# [2256 rows x 3 columns]

# %%
job_title = 'Data Analyst'
top_skills = 10

df_skills_final = df_skills_count[df_skills_count['job_title_short'] == job_title ].head(top_skills)
df_skills_final
# Out:
#     job_title_short  job_skills  skill_count
# 625    Data Analyst         sql        92428
# 494    Data Analyst       excel        66860
# 590    Data Analyst      python        57190
# 638    Data Analyst     tableau        46455
# 583    Data Analyst    power bi        39380
# 594    Data Analyst           r        29996
# 606    Data Analyst         sas        27998
# 585    Data Analyst  powerpoint        13822
# 664    Data Analyst        word        13562
# 605    Data Analyst         sap        11280

# %%
df_skills_final.plot(kind = 'barh', x = 'job_skills', y = 'skill_count')
# Out:
# <Axes: ylabel='job_skills'>

# %%
job_title = 'Data Engineer'
top_skills = 10

df_skills_final = df_skills_count[df_skills_count['job_title_short'] == job_title ].head(top_skills)
df_skills_final.plot(kind = 'barh', x = 'job_skills', y = 'skill_count')
plt.title(f"{top_skills} Top skills  for {job_title}")
plt.xlabel('Job Posting Count')
plt.legend().set_visible(False)
plt.show()
